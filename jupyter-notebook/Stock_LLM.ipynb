# %% [raw]
# from google import genai
# from google.genai import types

# %%
from IPython.display import Markdown, display

# %%
client = genai.Client(api_key="AIzaSyCEwBLnsGnz3RZzUFMth3u2gSVkhEX58WM")

# %%
model="gemini-2.5-flash"

# %%
prompt="What is the 5 day moving average stock price of Infosys in NSE "

# %%
sys_prompt= """ You are a Stock Market Research Analyst. Your goal is to provide high-quality insights.

Output Format:
- Use clear headings and bullet points
- Keep explanations concise but thorough
- Conclude with a summary recommendation

Tone: Professional, objective, educational, and trustworthy
"""

# %%
# Define the tool first
tools_list = {"google_search": {}}

# Then call the model
response = client.models.generate_content(
    model=model,
    contents=prompt,
    config={
        "system_instruction": sys_prompt,
        "tools": [tools_list] 
    }
)

# %%
display(Markdown(response.text))
# Out:
# ## Infosys (INFY) 5-Day Moving Average on NSE
#
# As of April 17, 2026, the 5-day moving average stock price for Infosys (INFY) on the National Stock Exchange (NSE) is ₹1305.08.
#
# The calculation is based on the closing prices for the last five trading days:
# *   **April 16, 2026:** ₹1,319.20
# *   **April 15, 2026:** ₹1,305.30
# *   **April 13, 2026:** ₹1,276.80
# *   **April 10, 2026:** ₹1,292.50
# *   **April 09, 2026:** ₹1,331.60
#
# The 5-day moving average is calculated by summing these closing prices and dividing by five:
# (1319.20 + 1305.30 + 1276.80 + 1292.50 + 1331.60) / 5 = 6525.40 / 5 = ₹1305.08.
#
# ### Summary Recommendation
#
# ...
